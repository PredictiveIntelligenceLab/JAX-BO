# %%
import numpy as onp
import jax.numpy as np
from jax import random, vmap, jvp
from jax.config import config
config.update("jax_enable_x64", True)

from scipy.optimize import minimize
from pyDOE import lhs
import matplotlib.pyplot as plt
from matplotlib import rc
from scipy.interpolate import griddata

from jaxbo.models import GradientGP
from jaxbo.utils import normalize_GradientGP, compute_w_gmm
from jaxbo.test_functions import *

onp.random.seed(1234)

# %%
# Define test function
f, p_x, dim, lb, ub = michalewicz()
# Gradient
def f_x(x):
    return jvp(f, (x,), (np.ones_like(x),))[1]

# Problem setttings
N = 5
noiseF = 0.0
noiseG = 0.0
options = {'kernel': 'RBF',
           'criterion': 'LW-LCB', 
           'input_prior': p_x,
           'kappa': 2.0,
           'nIter': 30}
gp_model = GradientGP(options)

# Fetch domain bounds
bounds = {'lb': lb, 'ub': ub}

# Initial training data
XF = lb + (ub-lb)*lhs(dim, N)
yF = vmap(f)(XF)
yF = yF + noiseF*yF.std(0)*onp.random.normal(yF.shape)

XG = XF
yG = vmap(f_x)(XG)
yG = yG + noiseG*yG.std(0)*onp.random.normal(yG.shape)

y = np.concatenate([yF, yG])

# Test data
if dim == 1:
    create_plots = True
    nn = 1000
    X_star = np.linspace(lb[0], ub[0], nn)[:,None]
    y_star = vmap(f)(X_star)
elif dim == 2:
    create_plots = True
    nn = 80
    xx = np.linspace(lb[0], ub[0], nn)
    yy = np.linspace(lb[1], ub[1], nn)
    XX, YY = np.meshgrid(xx, yy)
    X_star = np.concatenate([XX.flatten()[:,None], 
                             YY.flatten()[:,None]], axis = 1)
    y_star = vmap(f)(X_star)
else:
    create_plots = False
    nn = 20000
    X_star = lb + (ub-lb)*lhs(dim, nn)
    y_star = vmap(f)(X_star)

# True location of global minimum
idx_true = np.argmin(y_star)
true_x = X_star[idx_true,:]
true_y = y_star.min()
dom_bounds = tuple(map(tuple, np.vstack((lb, ub)).T))
result = minimize(f, true_x, jac=None, method='L-BFGS-B', bounds = dom_bounds)
true_x, true_y = result.x, result.fun

# %%
# Main Bayesian optimization loop
rng_key = random.PRNGKey(0)
for it in range(options['nIter']):
    print('-------------------------------------------------------------------')
    print('------------------------- Iteration %d/%d -------------------------' % (it+1, options['nIter']))
    print('-------------------------------------------------------------------')

    # Fetch normalized training data
    norm_batch, norm_const = normalize_GradientGP(XF, yF, XG, yG)

    # Train GP model
    print('Train GP...')
    rng_key = random.split(rng_key)[0]
    opt_params = gp_model.train(norm_batch,
                                rng_key,
                                num_restarts = 10)

    # Fit GMM
    if options['criterion'] == 'LW-LCB' or options['criterion'] == 'LW-US':
        print('Fit GMM...')
        rng_key = random.split(rng_key)[0]
        kwargs = {'params': opt_params,
                  'batch': norm_batch,
                  'norm_const': norm_const,
                  'bounds': bounds,
                  'rng_key': rng_key}
        gmm_vars = gp_model.fit_gmm(**kwargs, N_samples = 10000)
    else:
        gmm_vars = None

    # Compute next point via minimizing the acquisition function
    print('Computing next acquisition point...')
    kwargs = {'params': opt_params,
              'batch': norm_batch,
              'norm_const': norm_const,
              'bounds': bounds,
              'gmm_vars': gmm_vars}
    new_X = gp_model.compute_next_point_lbfgs(num_restarts=10, **kwargs)

    # Acquire data
    new_yF = vmap(f)(new_X)
    new_yF = new_yF + noiseF*new_yF.std(0)*onp.random.normal(new_yF.shape)
    
    new_yG = vmap(f_x)(new_X)
    new_yG = new_yG + noiseG*new_yG.std(0)*onp.random.normal(new_yG.shape)

    # Augment training data
    print('Updating data-set...')
    XF = np.concatenate([XF, new_X], axis = 0)
    XG = np.concatenate([XG, new_X], axis = 0)
    yF = np.concatenate([yF, new_yF])
    yG = np.concatenate([yG, new_yG])
    y = np.concatenate([yF, yG])

    # Print current best
    idx_best = np.argmin(yF)
    best_x = XF[idx_best,:]
    best_y = yF.min()
    print('True location: ({}), True value: {}'.format(true_x, true_y))
    print('Best location: ({}), Best value: {}'.format(best_x, best_y))
    print('New  location: ({}), New  value: {}'.format(new_X, new_yF))
# Out:
# -------------------------------------------------------------------
# ------------------------- Iteration 1/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.05866321 1.42791205]), Best value: -1.0039103744552418
# New  location: ([[1.58956421 1.57265828]]), New  value: [-1.00127378]
# -------------------------------------------------------------------
# ------------------------- Iteration 2/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.05866321 1.42791205]), Best value: -1.0039103744552418
# New  location: ([[1.60548889 1.86853714]]), New  value: [-0.01162548]
# -------------------------------------------------------------------
# ------------------------- Iteration 3/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.05866321 1.42791205]), Best value: -1.0039103744552418
# New  location: ([[1.62836415 1.21527871]]), New  value: [-0.01603488]
# -------------------------------------------------------------------
# ------------------------- Iteration 4/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.05866321 1.42791205]), Best value: -1.0039103744552418
# New  location: ([[1.47501066 1.41077316]]), New  value: [-0.38686352]
# -------------------------------------------------------------------
# ------------------------- Iteration 5/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.05866321 1.42791205]), Best value: -1.0039103744552418
# New  location: ([[1.34352607 1.63188473]]), New  value: [-0.85436443]
# -------------------------------------------------------------------
# ------------------------- Iteration 6/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.05866321 1.42791205]), Best value: -1.0039103744552418
# New  location: ([[1.65066221 1.55736069]]), New  value: [-0.99718506]
# -------------------------------------------------------------------
# ------------------------- Iteration 7/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.05866321 1.42791205]), Best value: -1.0039103744552418
# New  location: ([[1.91904233 1.76749764]]), New  value: [-0.34569941]
# -------------------------------------------------------------------
# ------------------------- Iteration 8/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.05866321 1.42791205]), Best value: -1.0039103744552418
# New  location: ([[1.16200066 1.46368361]]), New  value: [-0.64596951]
# -------------------------------------------------------------------
# ------------------------- Iteration 9/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([1.88438646 1.54570413]), Best value: -1.1030840648412046
# New  location: ([[1.88438646 1.54570413]]), New  value: [-1.10308406]
# -------------------------------------------------------------------
# ------------------------- Iteration 10/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([1.88438646 1.54570413]), Best value: -1.1030840648412046
# New  location: ([[1.33256871 1.98852241]]), New  value: [-2.34648826e-05]
# -------------------------------------------------------------------
# ------------------------- Iteration 11/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([1.88438646 1.54570413]), Best value: -1.1030840648412046
# New  location: ([[1.31058393 1.23702632]]), New  value: [-0.02128223]
# -------------------------------------------------------------------
# ------------------------- Iteration 12/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.20955326 1.55192066]), Best value: -1.7864222597784611
# New  location: ([[2.20955326 1.55192066]]), New  value: [-1.78642226]
# -------------------------------------------------------------------
# ------------------------- Iteration 13/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.20955326 1.55192066]), Best value: -1.7864222597784611
# New  location: ([[2.38423492 1.52354834]]), New  value: [-1.30242877]
# -------------------------------------------------------------------
# ------------------------- Iteration 14/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.20955326 1.55192066]), Best value: -1.7864222597784611
# New  location: ([[1.16614217 1.68439556]]), New  value: [-0.56787202]
# -------------------------------------------------------------------
# ------------------------- Iteration 15/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.20955326 1.55192066]), Best value: -1.7864222597784611
# New  location: ([[1.55826499 1.57795057]]), New  value: [-0.99867823]
# -------------------------------------------------------------------
# ------------------------- Iteration 16/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: ([2.20290515 1.57079609]), True value: -1.8013034100940637
# Best location: ([2.