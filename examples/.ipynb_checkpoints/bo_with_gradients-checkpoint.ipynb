# %%
import numpy as onp
import jax.numpy as np
from jax import random, vmap, jvp
from jax.config import config
config.update("jax_enable_x64", True)

from scipy.optimize import minimize
from pyDOE import lhs
import matplotlib.pyplot as plt
from matplotlib import rc
from scipy.interpolate import griddata

from jaxbo.models import GradientGP
from jaxbo.utils import normalize_GradientGP, compute_w_gmm
from jaxbo.test_functions import *

onp.random.seed(1234)

# %%
N = 5
noiseF = 0.0
noiseG = 0.0

options = {'kernel': 'RBF',
           'criterion': 'LW-LCB', 
           'kappa': 2.0,
           'nIter': 30}

# Define test function
f, p_x, dim, lb, ub = michalewicz()
def f_x(x):
    return jvp(f, (x,), (np.ones_like(x),))[1]

# Fetch domain bounds
bounds = {'lb': lb, 'ub': ub}

# Initial training data
XF = lb + (ub-lb)*lhs(dim, N)
yF = vmap(f)(XF)
yF = yF + noiseF*yF.std(0)*onp.random.normal(yF.shape)

XG = XF
yG = vmap(f_x)(XG)
yG = yG + noiseG*yG.std(0)*onp.random.normal(yG.shape)

y = np.concatenate([yF, yG])

# Test data
if dim == 1:
    create_plots = True
    nn = 1000
    X_star = np.linspace(lb[0], ub[0], nn)
    y_star = vmap(f)(X_star)
elif dim == 2:
    create_plots = True
    nn = 80
    xx = np.linspace(lb[0], ub[0], nn)
    yy = np.linspace(lb[1], ub[1], nn)
    XX, YY = np.meshgrid(xx, yy)
    X_star = np.concatenate([XX.flatten()[:,None], 
                             YY.flatten()[:,None]], axis = 1)
    y_star = vmap(f)(X_star)
else:
    create_plots = False
    nn = 20000
    X_star = lb + (ub-lb)*lhs(dim, nn)
    y_star = vmap(f)(X_star)

# True location of global minimum
idx_true = np.argmin(y_star)
true_x = X_star[idx_true,:]
true_y = y_star.min()
dom_bounds = tuple(map(tuple, np.vstack((lb, ub)).T))
result = minimize(f, true_x, jac=None, method='L-BFGS-B', bounds = dom_bounds)
true_x, true_y = result.x, result.fun
# Out:
# /Users/paris/opt/anaconda3/lib/python3.7/site-packages/jax/lib/xla_bridge.py:125: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
# Define model
gp_model = GradientGP(options)
rng_key = random.PRNGKey(0)

# Main Bayesian optimization loop
for it in range(options['nIter']):
    print('-------------------------------------------------------------------')
    print('------------------------- Iteration %d/%d -------------------------' % (it+1, options['nIter']))
    print('-------------------------------------------------------------------')

    # Fetch normalized training data
    norm_batch, norm_const = normalize_GradientGP(XF, yF, XG, yG)

    # Train GP model
    print('Train GP...')
    rng_key = random.split(rng_key)[0]
    opt_params = gp_model.train(norm_batch,
                                rng_key,
                                num_restarts = 10)

    # Fit GMM
    if options['criterion'] == 'LW-LCB' or options['criterion'] == 'LW-US':
        print('Fit GMM...')
        rng_key = random.split(rng_key)[0]
        gmm_vars = gp_model.fit_gmm(opt_params,
                                    norm_batch,
                                    norm_const,
                                    bounds,
                                    p_x,
                                    rng_key,
                                    N_samples = 10000)
    else:
        gmm_vars = None

    # Compute next point via minimizing the acquisition function
    print('Computing next acquisition point...')
    new_X = gp_model.compute_next_point(opt_params,
                                        norm_batch,
                                        norm_const,
                                        bounds,
                                        gmm_vars,
                                        num_restarts=10)

    # Acquire data
    new_yF = vmap(f)(new_X)
    new_yF = new_yF + noiseF*new_yF.std(0)*onp.random.normal(new_yF.shape)
    
    new_yG = vmap(f_x)(new_X)
    new_yG = new_yG + noiseG*new_yG.std(0)*onp.random.normal(new_yG.shape)

    # Augment training data
    print('Updating data-set...')
    XF = np.concatenate([XF, new_X], axis = 0)
    XG = np.concatenate([XG, new_X], axis = 0)
    yF = np.concatenate([yF, new_yF])
    yG = np.concatenate([yG, new_yG])
    y = np.concatenate([yF, yG])

    # Print current best
    idx_best = np.argmin(yF)
    best_x = XF[idx_best,:]
    best_y = yF.min()
    print('True location: (%f,%f), True value: %f' % (true_x[0], true_x[1], true_y))
    print('Best location: (%f,%f), Best value: %f' % (best_x[0], best_x[1], best_y))
    print('New  location: (%f,%f), New  value: %f' % (new_X[0,0], new_X[0,1], new_yF))
# Out:
# -------------------------------------------------------------------
# ------------------------- Iteration 1/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.058663,1.427912), Best value: -1.003910
# New  location: (1.600914,1.575316), New  value: -1.000932
# -------------------------------------------------------------------
# ------------------------- Iteration 2/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.058663,1.427912), Best value: -1.003910
# New  location: (1.678806,1.847191), New  value: -0.027477
# -------------------------------------------------------------------
# ------------------------- Iteration 3/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.058663,1.427912), Best value: -1.003910
# New  location: (1.511800,1.272395), New  value: -0.044602
# -------------------------------------------------------------------
# ------------------------- Iteration 4/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.058663,1.427912), Best value: -1.003910
# New  location: (1.284354,1.672657), New  value: -0.637072
# -------------------------------------------------------------------
# ------------------------- Iteration 5/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.058663,1.427912), Best value: -1.003910
# New  location: (1.602173,1.541270), New  value: -0.967722
# -------------------------------------------------------------------
# ------------------------- Iteration 6/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (1.964047,1.635258), Best value: -1.117155
# New  location: (1.964047,1.635258), New  value: -1.117155
# -------------------------------------------------------------------
# ------------------------- Iteration 7/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (1.964047,1.635258), Best value: -1.117155
# New  location: (1.391260,1.968817), New  value: -0.000091
# -------------------------------------------------------------------
# ------------------------- Iteration 8/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (1.964047,1.635258), Best value: -1.117155
# New  location: (1.236514,1.410694), New  value: -0.386389
# -------------------------------------------------------------------
# ------------------------- Iteration 9/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (1.964047,1.635258), Best value: -1.117155
# New  location: (1.883124,1.528293), New  value: -1.057293
# -------------------------------------------------------------------
# ------------------------- Iteration 10/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (1.964047,1.635258), Best value: -1.117155
# New  location: (1.796307,1.170983), New  value: -0.047764
# -------------------------------------------------------------------
# ------------------------- Iteration 11/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (1.964047,1.635258), Best value: -1.117155
# New  location: (1.756696,2.077766), New  value: -0.024693
# -------------------------------------------------------------------
# ------------------------- Iteration 12/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.194243,1.580191), Best value: -1.796500
# New  location: (2.194243,1.580191), New  value: -1.796500
# -------------------------------------------------------------------
# ------------------------- Iteration 13/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.194243,1.580191), Best value: -1.796500
# New  location: (2.345420,1.536577), New  value: -1.470177
# -------------------------------------------------------------------
# ------------------------- Iteration 14/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.194243,1.580191), Best value: -1.796500
# New  location: (1.483900,1.576059), New  value: -0.999029
# -------------------------------------------------------------------
# ------------------------- Iteration 15/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.194243,1.580191), Best value: -1.796500
# New  location: (1.086311,1.525336), New  value: -0.921795
# -------------------------------------------------------------------
# ------------------------- Iteration 16/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.194243,1.580191), Best value: -1.796500
# New  location: (1.609245,1.568583), New  value: -1.001865
# -------------------------------------------------------------------
# ------------------------- Iteration 17/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.194243,1.580191), Best value: -1.796500
# New  location: (1.388393,1.067432), New  value: -0.000255
# -------------------------------------------------------------------
# ------------------------- Iteration 18/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.194243,1.580191), Best value: -1.796500
# New  location: (1.087411,1.771653), New  value: -0.148752
# -------------------------------------------------------------------
# ------------------------- Iteration 19/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.194243,1.580191), Best value: -1.796500
# New  location: (2.223680,1.564886), New  value: -1.792847
# -------------------------------------------------------------------
# ------------------------- Iteration 20/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.196725,1.569379), Best value: -1.800603
# New  location: (2.196725,1.569379), New  value: -1.800603
# -------------------------------------------------------------------
# ------------------------- Iteration 21/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.196725,1.569379), Best value: -1.800603
# New  location: (2.008414,1.899918), New  value: -0.396076
# -------------------------------------------------------------------
# ------------------------- Iteration 22/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202738,1.571223), Best value: -1.801296
# New  location: (2.202738,1.571223), New  value: -1.801296
# -------------------------------------------------------------------
# ------------------------- Iteration 23/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202903,1.570749), Best value: -1.801303
# New  location: (2.202903,1.570749), New  value: -1.801303
# -------------------------------------------------------------------
# ------------------------- Iteration 24/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202858,1.570763), Best value: -1.801303
# New  location: (2.202858,1.570763), New  value: -1.801303
# -------------------------------------------------------------------
# ------------------------- Iteration 25/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202858,1.570763), Best value: -1.801303
# New  location: (1.181725,1.183630), New  value: -0.006153
# -------------------------------------------------------------------
# ------------------------- Iteration 26/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202854,1.570772), Best value: -1.801303
# New  location: (2.202854,1.570772), New  value: -1.801303
# -------------------------------------------------------------------
# ------------------------- Iteration 27/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202854,1.570772), Best value: -1.801303
# New  location: (2.202826,1.570772), New  value: -1.801303
# -------------------------------------------------------------------
# ------------------------- Iteration 28/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202854,1.570772), Best value: -1.801303
# New  location: (1.213704,2.040188), New  value: -0.000000
# -------------------------------------------------------------------
# ------------------------- Iteration 29/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202854,1.570778), Best value: -1.801303
# New  location: (2.202854,1.570778), New  value: -1.801303
# -------------------------------------------------------------------
# ------------------------- Iteration 30/30 -------------------------
# -------------------------------------------------------------------
# Train GP...
# Fit GMM...
# Computing next acquisition point...
# Updating data-set...
# True location: (2.202905,1.570796), True value: -1.801303
# Best location: (2.202854,1.570778), Best value: -1.801303
# New  location: (1.236260,1.540422), New  value: -0.963986

# %%
# Test accuracy
mean, std = gp_model.predict(X_star,
                             opt_params,
                             norm_batch,
                             norm_const)
lower = mean - 2.0*std
upper = mean + 2.0*std
# Check accuracy
error = np.linalg.norm(mean-y_star,2)/np.linalg.norm(y_star,2)
print("Relative L2 error u: %e" % (error))
# Out:
# Relative L2 error u: 6.897249e-01

# %%
if create_plots:
    # Compute predictions
    if options['criterion'] == 'LW-LCB' or options['criterion'] == 'LW-US':
        w_pred = compute_w_gmm(X_star, bounds, gmm_vars)
    else:
        w_pred = np.zeros(X_star.shape[0])
        
    acq_fun = lambda x: gp_model.acquisition(x,
                                             opt_params,
                                             norm_batch,
                                             norm_const,
                                             bounds,
                                             gmm_vars)
    a_pred = vmap(acq_fun)(X_star)
    x_new = gp_model.compute_next_point(opt_params,
                                        norm_batch,
                                        norm_const,
                                        bounds,
                                        gmm_vars,
                                        num_restarts=10)

    # Convert to NumPy
    X_star = onp.array(X_star)
    y_star = onp.array(y_star)
    mean = onp.array(mean)
    std = onp.array(std)
    w_pred = onp.array(w_pred)
    a_pred = onp.array(a_pred)
    XX = onp.array(XX)
    YY = onp.array(YY)
    Y_star = griddata(X_star, y_star, (XX, YY), method='cubic')
    Y_pred = griddata(X_star, mean, (XX, YY), method='cubic')
    Y_std  = griddata(X_star, std, (XX, YY), method='cubic')
    W_star = griddata(X_star, w_pred, (XX, YY), method='cubic')
    A_star = griddata(X_star, a_pred, (XX, YY), method='cubic')

    # Plot
    plt.rcParams.update({'font.size': 16})
    plt.rcParams['axes.linewidth']=3
    rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
    rc('text', usetex=True)

    plt.figure(figsize = (16,8))
    plt.subplot(1, 4, 1)
    fig = plt.contourf(XX, YY, Y_star)
    plt.plot(XF[:,0], XF[:,1], 'r.', ms = 6, alpha = 0.8)
    # plt.plot(true_x[0], true_x[1], 'md', ms = 8, alpha = 1.0)
    plt.xlabel(r'$x_1$')
    plt.ylabel(r'$x_2$')
    plt.title(r'Exact u(x)')
    plt.axis('square')

    plt.subplot(1, 4, 2)
    fig = plt.contourf(XX, YY, Y_pred)
    plt.xlabel(r'$x_1$')
    plt.ylabel(r'$x_2$')
    plt.title(r'Predicted mean')
    plt.axis('square')

    plt.subplot(1, 4, 3)
    fig = plt.contourf(XX, YY, 2.0*Y_std)
    plt.xlabel(r'$x_1$')
    plt.ylabel(r'$x_2$')
    plt.title(r'Two stds')
    plt.axis('square')

    plt.subplot(1, 4, 4)
    fig = plt.contourf(XX, YY, np.abs(Y_star-Y_pred))
    plt.xlabel(r'$x_1$')
    plt.ylabel(r'$x_2$')
    plt.title(r'Absolute error')
    plt.axis('square')
    plt.savefig('function_prediction.png', dpi = 300)

    idx_max = np.argmin(a_pred)
    plt.figure(figsize = (12,5))
    plt.subplot(1, 2, 1)
    fig = plt.contourf(XX, YY, W_star)
    plt.xlabel(r'$x_1$')
    plt.ylabel(r'$x_2$')
    plt.title(r'$w_{GMM}(x)$')
    plt.axis('square')
    plt.subplot(1, 2, 2)
    fig = plt.contourf(XX, YY, A_star)
    plt.colorbar(fig)
    # plt.plot(x0[:,0], x0[:,1], 'ms')
    # plt.plot(X_star[idx_max,0], X_star[idx_max,1], 'md')
    plt.plot(x_new[:,0], x_new[:,1], 'md', label = 'new X')
    plt.legend(frameon = False)
    plt.xlabel(r'$x_1$')
    plt.ylabel(r'$x_2$')
    plt.title(r'%s(x)' % (options['criterion']))
    plt.axis('square')
    plt.savefig('acquisition.png', dpi = 300)
